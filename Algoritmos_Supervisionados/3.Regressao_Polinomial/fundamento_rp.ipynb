# %% [markdown]
# # 📊 Algoritmos Supervisionados – Regressão Polinomial
#
# Neste módulo, vamos explorar o conceito de **polinômios** e aplicar a **regressão polinomial** para resolver problemas de modelagem preditiva.
#
# ## 🛠️ O que será desenvolvido
#
# Desenvolveremos um modelo completo, passando por todas as etapas:
#
# - Análise exploratória dos dados (**EDA**)
# - Treinamento do modelo
# - Entrega do modelo via **API**, permitindo o uso final por uma aplicação
#
# ## 🔍 Conceitos abordados
#
# - O conceito de **validação cruzada**, essencial para garantir a robustez do modelo
# - Técnicas para evitar o **overfitting**, garantindo previsões mais confiáveis
#
# > 🎯 O objetivo é entregar um pipeline de aprendizado supervisionado completo, pronto para uso no mundo real.
#
# ---
#
# # 📘 Polinômios
#
# Um polinômio é uma **expressão matemática** que representa a **soma de termos**, cada um consistindo de variáveis elevadas a **expoentes inteiros não-negativos**, multiplicadas por **coeficientes**.
#
# ## ✏️ Exemplo
#
# O polinômio `3x² + 2x − 5` contém os termos `3x²`, `2x` e `−5`.
#
# ## 📌 Termos importantes
#
# - **Coeficientes**: os números que multiplicam as variáveis (ex: 3 e 2 no exemplo).
# - **Expoentes**: indicam o grau de cada termo (ex: 2 em `3x²`).
# - **Grau do polinômio**: é o maior expoente entre os termos (neste caso, 2).
#
# ## 📐 Aplicações
#
# Polinômios são fundamentais em diversas áreas da matemática e ciências, sendo usados para:
#
# - Modelar relações
# - Resolver equações
# - Descrever padrões numéricos

# %% [markdown]
# ![image.png](attachment:image.png)
